# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict() # {word: index}
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list() # collect index
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count # list of tuples (word, count)
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) #{index: word}
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span) # thread-safe, memory efficient appends and pops opertions like `list`
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]]) # An ordered sentence

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'originated', 'anarchism', 'a', 'originated', 'as', 'of', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.885880
# Nearest to most: presse, welding, hangar, godlike, pompidou, nylon, drunk, darts,
# Nearest to was: janos, francois, maser, accademia, bahr, abendana, instituto, frunze,
# Nearest to into: depleted, traumas, mensch, federico, hitchens, liberal, daimlerchrysler, respectable,
# Nearest to a: stratocaster, ibn, geocaching, graecia, rejoining, delos, joked, vanish,
# Nearest to the: composing, nigger, affectionately, abruzzo, firmly, epistles, kassel, charismatic,
# Nearest to as: harnessing, kaspar, marmara, episcopate, label, lei, aragorn, layer,
# Nearest to four: helper, marlow, shouldn, spirits, jensen, lodged, discourage, mhz,
# Nearest to other: conciliar, caeiro, wherein, costing, cardboard, magnetopause, paddington, oneself,
# Nearest to see: regardless, chatting, egmont, conformance, backbones, ducas, deceptively, sio,
# Nearest to between: leper, decreed, selamat, tarentum, ets, gaia, discordian, spandau,
# Nearest to american: algirdas, panacea, intelligencer, docs, robbery, based, antitank, novell,
# Nearest to will: biologically, higham, disdain, supreme, toil, mammoths, viscosity, eddie,
# Nearest to who: antecedent, clade, pilgrim, luce, specializes, unsettling, cervical, maris,
# Nearest to system: weber, huguenot, presiding, anesthesia, surfin, academia, reigning, hula,
# Nearest to known: booted, kmt, comedies, renunciation, overlord, cost, mokhehle, troposphere,
# Nearest to an: ramadan, robinson, carat, orgasm, egregious, threatening, reductio, kievan,
# Average loss at step 2000: 4.355432
# Average loss at step 4000: 3.864771
# Average loss at step 6000: 3.786507
# Average loss at step 8000: 3.687906
# Average loss at step 10000: 3.609523
# Nearest to most: tl, pejorative, overwrite, dicrostonyx, kenji, sarcophagi, sts, whereby,
# Nearest to was: is, had, has, were, by, are, be, became,
# Nearest to into: durango, witherspoon, nchen, whether, perverse, from, depleted, terabytes,
# Nearest to a: the, any, rejoining, reverberation, malachi, propto, changed, ln,
# Nearest to the: its, a, his, this, their, schwerin, bithynia, hesse,
# Nearest to as: clementine, rag, elliptic, astm, by, is, afghan, along,
# Nearest to four: six, seven, five, eight, three, two, nine, zero,
# Nearest to other: conciliar, many, enormous, laetrile, cardboard, collagen, different, sixth,
# Nearest to see: regardless, rohe, egmont, deceptively, tribunal, conformance, massif, chatting,
# Nearest to between: tarentum, leper, with, selamat, replenished, borrower, kingsley, packers,
# Nearest to american: dartmoor, paxton, accusing, branched, antitank, algirdas, assemblages, damon,
# Nearest to will: toil, agnosticism, biologically, can, port, cellar, treatises, higham,
# Nearest to who: he, specializes, clade, antecedent, pilgrim, and, demoted, selkirk,
# Nearest to system: hula, weber, paralysis, huguenot, academia, ps, casta, anesthesia,
# Nearest to known: booted, hellenized, essential, such, kmt, well, seen, discounted,
# Nearest to an: elevating, the, bengali, renarrative, depends, spinal, kievan, how,
# Average loss at step 12000: 3.604807
# Average loss at step 14000: 3.572349
# Average loss at step 16000: 3.405872
# Average loss at step 18000: 3.458629
# Average loss at step 20000: 3.541524
# Nearest to most: more, some, whereby, cephalon, many, tl, donohue, televangelist,
# Nearest to was: is, has, were, had, became, by, nashville, be,
# Nearest to into: from, through, durango, off, whether, under, witherspoon, perverse,
# Nearest to a: dose, any, stratocaster, rejoining, theosis, this, the, malachi,
# Nearest to the: their, its, his, this, salerno, an, mattia, a,
# Nearest to as: elliptic, for, conics, suppl, blues, toleration, kwajalein, standoff,
# Nearest to four: seven, six, five, three, eight, two, nine, one,
# Nearest to other: many, these, different, sixth, laetrile, some, such, independently,
# Nearest to see: minas, massif, rohe, regardless, can, casper, egmont, venn,
# Nearest to between: with, from, tarentum, annoying, among, in, during, prizes,
# Nearest to american: french, dartmoor, romanian, legalized, slaves, appalling, accepting, austrian,
# Nearest to will: would, can, may, could, toil, should, to, riddled,
# Nearest to who: he, which, they, then, clade, also, retitled, often,
# Nearest to system: hula, paralysis, casta, ps, weber, erm, aesthetics, huguenot,
# Nearest to known: such, booted, seen, essential, well, hellenized, geothermal, coding,
# Nearest to an: the, bengali, powerplant, spinal, mansion, renarrative, hana, underlie,
# Average loss at step 22000: 3.498212
# Average loss at step 24000: 3.490519
# Average loss at step 26000: 3.480463
# Average loss at step 28000: 3.483862
# Average loss at step 30000: 3.501998
# Nearest to most: some, more, among, whereby, many, overwrite, tl, cephalon,
# Nearest to was: is, were, has, had, became, been, be, expresses,
# Nearest to into: from, under, through, durango, off, after, within, whether,
# Nearest to a: the, theosis, regarded, organisational, deformed, wipe, alias, any,
# Nearest to the: their, its, his, andorra, a, some, diarist, seydlitz,
# Nearest to as: under, elliptic, disparity, standoff, clementine, kwajalein, blues, afghan,
# Nearest to four: five, six, eight, seven, three, nine, two, zero,
# Nearest to other: many, these, different, some, scorn, cuvier, arden, such,
# Nearest to see: minas, rohe, massif, but, facsimile, alchemical, autonomous, tribunal,
# Nearest to between: with, among, from, in, tarentum, replenished, where, annoying,
# Nearest to american: austrian, british, french, legalized, accepting, english, industries, dartmoor,
# Nearest to will: can, would, may, could, should, must, to, might,
# Nearest to who: he, they, which, not, also, dragoons, it, under,
# Nearest to system: systems, paralysis, casta, hula, aim, academia, erm, ps,
# Nearest to known: such, used, well, booted, seen, regarded, interment, essential,
# Nearest to an: spinal, vectors, incomes, mansion, lowell, powerplant, underlie, sissy,
# Average loss at step 32000: 3.499795
# Average loss at step 34000: 3.491296
# Average loss at step 36000: 3.451813
# Average loss at step 38000: 3.303933
# Average loss at step 40000: 3.432264
# Nearest to most: more, many, some, among, exerted, dicrostonyx, whereby, less,
# Nearest to was: is, were, had, became, has, been, be, being,
# Nearest to into: through, from, under, durango, off, witherspoon, within, perverse,
# Nearest to a: the, or, insecticides, suitable, aster, another, any, interlocking,
# Nearest to the: their, a, its, any, this, his, each, sherbrooke,
# Nearest to as: by, asparagales, clementine, when, cayman, spawning, royals, myung,
# Nearest to four: three, six, five, seven, eight, two, nine, one,
# Nearest to other: different, piss, many, leonis, various, several, cuvier, baltic,
# Nearest to see: minas, can, include, list, rohe, rollin, cleanliness, according,
# Nearest to between: with, among, from, replenished, during, tarentum, against, in,
# Nearest to american: french, austrian, accepting, british, japanese, international, english, htm,
# Nearest to will: would, can, could, may, should, must, might, does,
# Nearest to who: he, which, they, also, often, she, crested, flexible,
# Nearest to system: systems, hula, paralysis, issue, ignores, casta, typology, weber,
# Nearest to known: such, used, regarded, well, defined, booted, interment, essential,
# Nearest to an: lowell, vectors, spinal, powerplant, xc, another, somehow, underlie,
# Average loss at step 42000: 3.437020
# Average loss at step 44000: 3.454653
# Average loss at step 46000: 3.450474
# Average loss at step 48000: 3.353859
# Average loss at step 50000: 3.379642
# Nearest to most: more, less, many, among, some, whereby, particularly, hypothalamus,
# Nearest to was: is, became, has, were, had, by, sash, be,
# Nearest to into: through, from, under, durango, within, impending, back, off,
# Nearest to a: the, any, another, theosis, suitable, rejoining, no, willingness,
# Nearest to the: its, their, his, a, any, apps, seasonally, superstitious,
# Nearest to as: elliptic, suppress, judgements, quadrature, when, hulk, landau, separatists,
# Nearest to four: five, six, eight, seven, three, nine, two, zero,
# Nearest to other: different, many, various, several, these, leonis, some, cuvier,
# Nearest to see: include, minas, ilo, facsimile, according, malinche, massif, gk,
# Nearest to between: with, among, from, in, against, across, foley, smear,
# Nearest to american: english, french, international, austrian, romanian, accepting, british, htm,
# Nearest to will: would, can, could, may, should, must, might, does,
# Nearest to who: he, which, she, they, also, brady, not, palmerston,
# Nearest to system: systems, casta, paralysis, hula, ignores, weber, anesthesia, issue,
# Nearest to known: used, such, regarded, defined, booted, seen, well, rrna,
# Nearest to an: lowell, somehow, the, underlie, another, spinal, pharmacology, xc,
# Average loss at step 52000: 3.436521
# Average loss at step 54000: 3.425604
# Average loss at step 56000: 3.440653
# Average loss at step 58000: 3.394178
# Average loss at step 60000: 3.390245
# Nearest to most: some, many, more, less, all, among, use, particularly,
# Nearest to was: is, became, had, were, has, be, elca, although,
# Nearest to into: through, from, under, within, around, across, approx, over,
# Nearest to a: the, any, another, olympia, dose, this, malachi, aster,
# Nearest to the: their, its, a, some, this, his, any, your,
# Nearest to as: nottinghamshire, elliptic, standoff, disparity, residual, harnessing, disruption, dib,
# Nearest to four: six, five, eight, seven, three, nine, zero, two,
# Nearest to other: different, various, many, academic, aldous, piss, emissions, ailing,
# Nearest to see: include, minas, list, massif, can, including, gk, erode,
# Nearest to between: with, among, from, within, replenished, in, shaping, undermines,
# Nearest to american: english, international, romanian, british, austrian, french, dict, australian,
# Nearest to will: would, can, could, may, should, must, might, does,
# Nearest to who: he, which, still, she, now, they, never, also,
# Nearest to system: systems, paralysis, hula, issue, line, casta, ignores, weber,
# Nearest to known: used, such, regarded, defined, described, well, essential, interment,
# Nearest to an: xc, lowell, somehow, calypso, pharmacology, spinal, incomes, kislev,
# Average loss at step 62000: 3.240079
# Average loss at step 64000: 3.252189
# Average loss at step 66000: 3.398108
# Average loss at step 68000: 3.390812
# Average loss at step 70000: 3.362092
# Nearest to most: more, some, many, less, particularly, use, broadbent, among,
# Nearest to was: is, has, were, became, had, been, elca, nashville,
# Nearest to into: from, through, within, under, impending, across, off, approx,
# Nearest to a: another, the, suitable, any, dose, nnrot, trusteeship, camphor,
# Nearest to the: their, its, any, a, this, these, another, some,
# Nearest to as: easternmost, elliptic, caps, cyclones, hogg, toleration, vegan, bilinear,
# Nearest to four: six, five, seven, three, eight, nine, zero, two,
# Nearest to other: many, various, different, some, ailing, academic, such, leonis,
# Nearest to see: include, list, can, minas, massif, and, comorian, refers,
# Nearest to between: among, with, within, from, cumulative, gerry, shaping, patronage,
# Nearest to american: english, romanian, british, reorganisation, french, african, cuban, dict,
# Nearest to will: would, could, can, may, should, must, might, cannot,
# Nearest to who: he, they, still, now, there, never, which, often,
# Nearest to system: systems, ignores, cuneiform, weber, paralysis, problem, afrikaans, aesthetics,
# Nearest to known: used, such, regarded, defined, described, seen, well, classified,
# Nearest to an: xc, underlie, another, the, lowell, powerplant, vectors, worry,
# Average loss at step 72000: 3.373192
# Average loss at step 74000: 3.346714
# Average loss at step 76000: 3.311201
# Average loss at step 78000: 3.349449
# Average loss at step 80000: 3.375728
# Nearest to most: more, many, some, particularly, less, among, broadbent, rhea,
# Nearest to was: is, became, were, had, has, elca, been, sash,
# Nearest to into: through, from, within, off, under, across, towards, durango,
# Nearest to a: the, another, paganism, theosis, philippians, olympia, aster, willingness,
# Nearest to the: a, its, his, their, this, meg, muppets, surfacing,
# Nearest to as: before, elliptic, qualcomm, including, easternmost, graeco, keene, popolo,
# Nearest to four: five, six, seven, eight, three, two, nine, zero,
# Nearest to other: various, different, many, leonis, others, piss, academic, including,
# Nearest to see: include, refers, refer, but, minas, according, satchmo, comorian,
# Nearest to between: among, with, within, from, shaping, in, around, over,
# Nearest to american: british, reorganisation, america, romanian, cuban, french, international, spanish,
# Nearest to will: would, could, may, can, must, should, might, cannot,
# Nearest to who: which, he, never, still, they, she, crested, usually,
# Nearest to system: systems, ignores, cuneiform, nfs, problem, paralysis, properly, metcalfe,
# Nearest to known: used, regarded, defined, such, described, classified, seen, considered,
# Nearest to an: vectors, somehow, xc, calypso, restored, lowell, underlie, claus,
# Average loss at step 82000: 3.410293
# Average loss at step 84000: 3.413010
# Average loss at step 86000: 3.387920
# Average loss at step 88000: 3.351958
# Average loss at step 90000: 3.364978
# Nearest to most: more, some, less, many, particularly, among, broadbent, several,
# Nearest to was: is, became, had, were, has, be, elca, been,
# Nearest to into: through, from, within, curls, across, under, argyll, around,
# Nearest to a: the, another, any, paganism, philippians, aster, suitable, halicarnassus,
# Nearest to the: its, this, his, a, each, their, any, hilt,
# Nearest to as: elliptic, approx, easternmost, keene, freising, lymphoid, judgements, stillborn,
# Nearest to four: seven, five, eight, three, six, two, nine, one,
# Nearest to other: various, smaller, different, older, leonis, piss, mendel, academic,
# Nearest to see: includes, alvar, refer, threefold, list, mutable, isuzu, minas,
# Nearest to between: among, with, from, within, against, through, around, during,
# Nearest to american: british, french, romanian, african, italian, german, cuban, russian,
# Nearest to will: would, can, could, may, must, should, might, cannot,
# Nearest to who: he, which, never, still, crested, she, but, they,
# Nearest to system: systems, problem, ignores, version, issue, model, process, deformations,
# Nearest to known: regarded, used, such, described, defined, seen, well, available,
# Nearest to an: lowell, xc, vectors, pharmacology, amu, another, somehow, acted,
# Average loss at step 92000: 3.398779
# Average loss at step 94000: 3.250506
# Average loss at step 96000: 3.354008
# Average loss at step 98000: 3.239934
# Average loss at step 100000: 3.357479
# Nearest to most: more, less, some, particularly, many, several, enthusiastically, use,
# Nearest to was: is, became, were, has, had, elca, been, being,
# Nearest to into: through, from, within, across, curls, iwerks, argyll, around,
# Nearest to a: the, another, any, camphor, paganism, olympia, dose, wessel,
# Nearest to the: his, its, their, a, your, meg, s, muppets,
# Nearest to as: elliptic, when, vegan, easternmost, toleration, dib, freising, caps,
# Nearest to four: seven, six, five, eight, two, nine, three, zero,
# Nearest to other: various, arden, caicos, smaller, duality, piss, others, different,
# Nearest to see: refers, includes, refer, references, can, list, minas, isuzu,
# Nearest to between: among, with, against, within, around, bolstered, from, loch,
# Nearest to american: british, romanian, russian, canadian, french, italian, ted, australian,
# Nearest to will: would, could, can, must, should, may, might, cannot,
# Nearest to who: he, still, she, probably, never, which, often, also,
# Nearest to system: systems, nfs, ignores, paralysis, model, process, pointwise, benefiting,
# Nearest to known: such, regarded, used, defined, described, seen, available, classified,
# Nearest to an: xc, vectors, another, lowell, sejong, phrygia, calypso, underlie,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
# Out:
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/collections.py:548: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == 'face':

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %% [markdown]
# From the paper [Efficient Estimation of Word Representations in Vector Space](http://arxiv.org/pdf/1301.3781v3.pdf), it describes the architecture of CBOW and skip-gram as:
# > The CBOW architecture predicts the current word based on the
# context, and the Skip-gram predicts surrounding words given the current word.
#
# Also, in CBOW model:
# > the weight matrix between the input and the projection layer is shared for all word positions in the same
# way as in the NNLM.
#
# Therefore, I write out the decision function of CBOW in psudo code:
#
# `
# projection(word_0) = sum([(word_i * W + B) for word_i in surrounding_words])
# `
#
# Then the loss should be:
#
# `
# sampled_softmax_loss(projection(word_0), word_0)
# `
#
# CBOW should require its input data and labels in the following form:
#
# `
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#
# batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of'], ['term', 'abuse'], ['of','first']]
#
# labels: ['originated', 'as', 'a', 'term', 'of', 'abuse']
# `
#
# So I need to write a new `generate_batch` function first.
#
# Then use the `tf.nn.embedding_lookup_sparse` function:
#
# https://github.com/tensorflow/tensorflow/issues/342

# %%
from itertools import compress

data_index = 0

def generate_batch_CBOW(batch_size, num_skips, skip_window):
  '''
  batch should be a shape of (batch_size, num_skips)
    batch_size: number of words in each mini-batch
    num_skips: number of surrounding words on both direction (2: one word ahead and one word following)
    skip_window: number of words at both ends of a sentence to skip (1: skip the first and last word of a sentence)
  '''  
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size, num_skips), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span) # used for collecting data[data_index] in the sliding window
  # collect the first window of words
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  # move the sliding window  
  for i in range(batch_size):
    mask = [1] * span
    mask[skip_window] = 0 
    batch[i, :] = list(compress(buffer, mask)) # all surrounding words
    labels[i, 0] = buffer[skip_window] # the word at the center 
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]]) # An ordered sentence

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch_CBOW(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [[reverse_dictionary[i] for i in bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of'], ['term', 'abuse'], ['of', 'first'], ['abuse', 'used'], ['first', 'against']]
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#
# with num_skips = 4 and skip_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first'], ['term', 'of', 'first', 'used'], ['of', 'abuse', 'used', 'against'], ['abuse', 'first', 'against', 'early'], ['first', 'used', 'early', 'working']]
#     labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, num_skips])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  # Computes the sum of embedding vectors for the given ids
  embed = tf.zeros([batch_size, embedding_size])
  for j in range(num_skips):
    embed += tf.nn.embedding_lookup(embeddings, train_dataset[:, j])
    
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch_CBOW(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.006255
# Nearest to they: incomprehensible, innocuous, suns, gila, disguising, tells, dq, old,
# Nearest to had: dieter, hellboy, amortized, stallone, constituents, eg, kondratiev, elevating,
# Nearest to five: infrequently, intriguing, delays, tapered, nude, vegetables, complaints, load,
# Nearest to at: varphi, christoph, bureaucrats, enabling, elixir, serre, blish, boastful,
# Nearest to its: october, smuggling, promote, whitacre, gateways, wilhelmshaven, attaching, kushan,
# Nearest to or: baluchistan, monochromatic, sugar, kubitzki, since, insights, windowing, tragedians,
# Nearest to nine: nen, battles, manure, inquirer, rear, holdings, offended, acquisitions,
# Nearest to and: miner, recoup, shown, malenkov, incarceration, brin, pickard, vacationing,
# Nearest to about: termite, moravia, overgrazing, influenced, shipments, implants, gz, opportunistic,
# Nearest to more: reminiscent, starches, americanized, constitutionally, simd, conferred, hummingbird, usefulness,
# Nearest to state: predating, contacted, polypropylene, arcseconds, amp, semite, messier, pamplona,
# Nearest to a: masculine, nig, symbolic, ockham, doubtless, kochi, eindhoven, laodiceans,
# Nearest to people: opec, tahitian, roads, rockabilly, oversaw, redefining, nagoya, continental,
# Nearest to during: lasi, arabah, sleep, blooded, beards, meditations, groot, cordon,
# Nearest to that: checkers, halts, misalignment, corrupted, shrewsbury, byzantine, loyalist, steps,
# Nearest to first: outpouring, punks, anomaly, dwelt, cgpm, concr, hypoglycemic, moor,
# Average loss at step 2000: 4.097511
# Average loss at step 4000: 3.556250
# Average loss at step 6000: 3.386448
# Average loss at step 8000: 3.243808
# Average loss at step 10000: 3.180457
# Nearest to they: he, we, you, there, who, bengal, she, targaryen,
# Nearest to had: has, have, was, were, remarriage, having, lactamase, accommodating,
# Nearest to five: six, eight, four, nine, seven, three, zero, two,
# Nearest to at: in, on, diaconate, despite, enabling, routledge, with, transform,
# Nearest to its: their, his, the, airman, chipmunk, ripe, blackmailed, devastating,
# Nearest to or: and, than, blocker, clarify, surely, depraved, guido, peasant,
# Nearest to nine: six, eight, seven, five, four, three, zero, two,
# Nearest to and: or, ez, dissolves, vehement, epithelial, strewn, laurier, ex,
# Nearest to about: gatehouse, ulfilas, within, rd, shipments, overgrazing, compendium, fonni,
# Nearest to more: less, most, examination, lfc, xis, supportive, dimitri, abigail,
# Nearest to state: predating, amp, lillee, magnetosphere, coding, contacted, befriends, asymptotes,
# Nearest to a: the, any, this, replicate, clu, pilsner, zeta, doubtless,
# Nearest to people: caicos, lovecraft, mainline, till, crime, idea, skeletal, tahitian,
# Nearest to during: while, columbian, cordon, after, on, in, blooded, lasi,
# Nearest to that: which, upcoming, what, cave, entity, this, gerund, goryeo,
# Nearest to first: outpouring, alfalfa, hen, third, punks, cgpm, brat, comiskey,
# Average loss at step 12000: 3.204081
# Average loss at step 14000: 3.155304
# Average loss at step 16000: 3.178367
# Average loss at step 18000: 3.126062
# Average loss at step 20000: 2.988213
# Nearest to they: we, he, there, you, these, i, she, it,
# Nearest to had: has, have, was, having, never, accommodating, were, wanted,
# Nearest to five: six, seven, eight, three, four, nine, zero, two,
# Nearest to at: near, on, during, in, diaconate, despite, after, relieving,
# Nearest to its: their, his, her, the, alberts, airman, chipmunk, sampled,
# Nearest to or: and, than, ymca, equivalency, rugrats, xers, mono, italics,
# Nearest to nine: eight, seven, six, five, four, zero, three, one,
# Nearest to and: or, but, dominatrices, undertakings, grapefruit, gls, while, sperm,
# Nearest to about: gatehouse, within, expressly, leste, rd, fasttrack, polio, fonni,
# Nearest to more: less, most, very, greater, rather, flame, examination, organising,
# Nearest to state: befriends, contacted, magnetosphere, durrani, nightclub, adsl, predating, ihr,
# Nearest to a: the, another, any, his, no, zeta, replicate, your,
# Nearest to people: caicos, goods, countries, fairway, mainline, lovecraft, redefining, interrogation,
# Nearest to during: in, after, at, on, against, from, chronicling, brisance,
# Nearest to that: which, this, what, however, corel, logistical, goryeo, but,
# Nearest to first: next, last, outpouring, second, alfalfa, vatsetis, third, least,
# Average loss at step 22000: 3.071777
# Average loss at step 24000: 3.036741
# Average loss at step 26000: 3.006985
# Average loss at step 28000: 3.028307
# Average loss at step 30000: 3.005826
# Nearest to they: we, there, he, you, she, it, these, who,
# Nearest to had: has, have, was, having, were, accommodating, never, nexus,
# Nearest to five: six, four, seven, nine, three, eight, zero, two,
# Nearest to at: during, near, despite, disputed, in, debug, on, milky,
# Nearest to its: their, his, the, her, alberts, phidias, sinclair, airman,
# Nearest to or: and, than, dtp, gnumeric, heed, carbonated, citro, opined,
# Nearest to nine: seven, eight, six, four, five, zero, three, two,
# Nearest to and: or, but, arnstadt, infertility, grievous, applicability, theorizes, africaine,
# Nearest to about: gatehouse, stole, expressly, over, within, gottes, polio, fonni,
# Nearest to more: less, most, very, greater, rather, longer, organising, larger,
# Nearest to state: magnetosphere, befriends, government, nightclub, mutiny, ihr, barrows, contacted,
# Nearest to a: the, any, another, isolates, frightful, palermo, this, krypton,
# Nearest to people: children, countries, men, caicos, scouts, words, fairway, others,
# Nearest to during: in, after, before, from, at, brisance, since, when,
# Nearest to that: which, however, what, where, this, generally, corel, goryeo,
# Nearest to first: next, last, second, final, third, alfalfa, vatsetis, only,
# Average loss at step 32000: 2.828204
# Average loss at step 34000: 2.956279
# Average loss at step 36000: 2.951264
# Average loss at step 38000: 2.942428
# Average loss at step 40000: 2.931580
# Nearest to they: we, there, he, you, she, i, it, who,
# Nearest to had: has, have, having, were, was, wanted, never, accommodating,
# Nearest to five: six, four, seven, eight, three, zero, nine, two,
# Nearest to at: near, during, embouchure, enabling, alienate, steered, oven, in,
# Nearest to its: their, his, her, the, chipmunk, your, my, alberts,
# Nearest to or: and, than, autographed, dari, regatta, gorges, rann, ems,
# Nearest to nine: eight, six, seven, five, four, zero, three, two,
# Nearest to and: or, but, while, laurier, including, arminians, dominatrices, africaine,
# Nearest to about: within, over, stole, missing, larousse, widened, polio, that,
# Nearest to more: less, very, most, larger, rather, greater, better, increasingly,
# Nearest to state: nightclub, states, council, befriends, magnetosphere, augmentation, ihr, barrows,
# Nearest to a: another, the, afterthought, dissimilar, pilsner, quadrature, replicate, iit,
# Nearest to people: men, children, caicos, countries, jews, scouts, scholars, others,
# Nearest to during: in, after, before, when, despite, since, from, throughout,
# Nearest to that: which, however, what, where, crevasses, corel, confusing, about,
# Nearest to first: last, second, next, final, third, vatsetis, earliest, hen,
# Average loss at step 42000: 2.951810
# Average loss at step 44000: 2.957118
# Average loss at step 46000: 2.907087
# Average loss at step 48000: 2.870333
# Average loss at step 50000: 2.849462
# Nearest to they: we, there, you, he, she, it, these, withheld,
# Nearest to had: has, have, having, was, accommodating, were, wanted, did,
# Nearest to five: four, seven, eight, six, nine, three, zero, two,
# Nearest to at: during, in, debug, near, gotlanders, despite, embouchure, fairmount,
# Nearest to its: their, his, her, the, alberts, whose, your, quan,
# Nearest to or: and, than, though, sikh, nutshell, mega, nasi, diurnal,
# Nearest to nine: eight, seven, six, four, five, zero, three, two,
# Nearest to and: or, but, while, including, american, than, brahmin, crop,
# Nearest to about: missing, stole, interstellar, wilhelmina, gatehouse, larousse, palatinate, judaeo,
# Nearest to more: less, most, very, rather, larger, greater, longer, smaller,
# Nearest to state: nightclub, city, ihr, states, befriends, government, magnetosphere, gc,
# Nearest to a: the, any, another, pilsner, frightful, krypton, clu, designating,
# Nearest to people: children, men, players, women, countries, jews, others, caicos,
# Nearest to during: in, before, after, until, although, from, despite, when,
# Nearest to that: which, what, however, goryeo, why, it, whom, corel,
# Nearest to first: last, next, second, final, third, original, unger, earliest,
# Average loss at step 52000: 2.891208
# Average loss at step 54000: 2.863635
# Average loss at step 56000: 2.859805
# Average loss at step 58000: 2.744287
# Average loss at step 60000: 2.826724
# Nearest to they: we, you, he, there, she, it, unser, who,
# Nearest to had: has, have, was, having, accommodating, were, never, wanted,
# Nearest to five: seven, six, four, eight, nine, three, zero, two,
# Nearest to at: during, in, on, within, under, near, milky, alienate,
# Nearest to its: their, his, her, the, whose, our, your, frites,
# Nearest to or: and, than, liang, hamid, megaliths, ems, blocker, autographed,
# Nearest to nine: eight, seven, six, five, four, zero, three, one,
# Nearest to and: or, but, although, while, esse, byrnes, africaine, including,
# Nearest to about: within, expressly, judaeo, missing, panthera, loud, larousse, regarding,
# Nearest to more: less, greater, rather, most, larger, very, smaller, longer,
# Nearest to state: states, befriends, nightclub, council, mutiny, ihr, magnetosphere, contacted,
# Nearest to a: another, the, vanished, any, portage, quadrature, palermo, farouk,
# Nearest to people: men, children, players, others, women, person, anyone, jews,
# Nearest to during: after, in, when, before, within, despite, although, through,
# Nearest to that: which, however, what, whom, how, goryeo, elca, crevasses,
# Nearest to first: second, last, next, third, final, original, earliest, affonso,
# Average loss at step 62000: 2.838526
# Average loss at step 64000: 2.772276
# Average loss at step 66000: 2.764585
# Average loss at step 68000: 2.717591
# Average loss at step 70000: 2.788938
# Nearest to they: we, he, you, there, she, it, these, who,
# Nearest to had: has, have, having, was, were, accommodating, focussed, eventually,
# Nearest to five: six, seven, nine, four, three, eight, zero, two,
# Nearest to at: near, in, on, during, under, embouchure, ixion, yr,
# Nearest to its: their, his, the, her, alberts, our, whose, quan,
# Nearest to or: and, than, though, scraps, withdrawing, canonized, ems, usn,
# Nearest to nine: eight, seven, five, six, four, three, zero, two,
# Nearest to and: or, but, including, rover, however, bains, although, cliques,
# Nearest to about: expressly, missing, larousse, sei, polio, judaeo, metamorphism, within,
# Nearest to more: less, most, greater, very, rather, quite, larger, highly,
# Nearest to state: states, government, nightclub, befriends, mutiny, council, governor, barrows,
# Nearest to a: the, another, any, pilsner, every, vanished, bittersweet, mjt,
# Nearest to people: children, men, women, jews, players, person, words, anyone,
# Nearest to during: in, after, despite, since, within, throughout, before, when,
# Nearest to that: which, what, however, where, goryeo, crevasses, but, why,
# Nearest to first: second, next, last, third, comiskey, previous, hen, original,
# Average loss at step 72000: 2.796152
# Average loss at step 74000: 2.640718
# Average loss at step 76000: 2.803936
# Average loss at step 78000: 2.823842
# Average loss at step 80000: 2.779502
# Nearest to they: we, you, he, there, she, it, i, others,
# Nearest to had: has, have, having, was, were, wanted, accommodating, eventually,
# Nearest to five: six, seven, eight, four, nine, three, zero, two,
# Nearest to at: during, in, near, despite, within, hon, demyelinating, alienate,
# Nearest to its: their, his, the, whose, her, alberts, phidias, your,
# Nearest to or: and, than, though, withdrawing, autographed, crafty, nasi, stereoisomers,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to and: or, including, but, falsetto, although, firstnode, rover, which,
# Nearest to about: larousse, goodwin, missing, expressly, metamorphism, widened, stole, that,
# Nearest to more: less, very, most, rather, quite, greater, larger, highly,
# Nearest to state: states, council, durrani, sovereign, befriends, wellesley, nightclub, barrows,
# Nearest to a: another, the, vanished, sayer, clu, bittersweet, pilsner, heartfelt,
# Nearest to people: men, children, players, women, others, person, jews, persons,
# Nearest to during: in, after, before, when, at, despite, until, under,
# Nearest to that: which, what, however, why, where, prakrit, suspecting, instead,
# Nearest to first: next, last, second, third, earliest, best, final, fourth,
# Average loss at step 82000: 2.667917
# Average loss at step 84000: 2.770138
# Average loss at step 86000: 2.734203
# Average loss at step 88000: 2.755357
# Average loss at step 90000: 2.736557
# Nearest to they: we, you, there, he, she, i, it, who,
# Nearest to had: has, have, having, was, tries, wanted, were, contributed,
# Nearest to five: six, four, seven, eight, three, nine, zero, two,
# Nearest to at: near, in, during, within, despite, milky, on, alienate,
# Nearest to its: their, his, the, her, whose, alberts, your, our,
# Nearest to or: and, than, diurnal, though, soninke, withdrawing, while, le,
# Nearest to nine: eight, seven, six, four, five, zero, three, two,
# Nearest to and: or, including, africaine, but, although, etc, nor, pals,
# Nearest to about: missing, around, widened, stole, larousse, goodwin, judaeo, sei,
# Nearest to more: less, most, very, quite, rather, increasingly, greater, better,
# Nearest to state: states, nightclub, malvinas, durrani, crippling, city, befriends, magnetosphere,
# Nearest to a: another, the, sayer, hesitant, kilocalories, tolson, krypton, heartfelt,
# Nearest to people: men, children, women, persons, players, person, jews, things,
# Nearest to during: in, after, before, despite, within, when, since, catheter,
# Nearest to that: which, what, however, how, where, why, goryeo, who,
# Nearest to first: next, second, last, third, earliest, best, previous, smallest,
# Average loss at step 92000: 2.680892
# Average loss at step 94000: 2.726331
# Average loss at step 96000: 2.697372
# Average loss at step 98000: 2.369022
# Average loss at step 100000: 2.404004
# Nearest to they: we, he, you, there, she, i, it, eventually,
# Nearest to had: has, have, having, was, tries, never, suffered, is,
# Nearest to five: seven, four, six, eight, three, nine, zero, two,
# Nearest to at: during, in, near, despite, on, copra, yr, hon,
# Nearest to its: their, his, her, whose, your, alberts, the, our,
# Nearest to or: and, than, nor, though, nasi, autographed, ryu, drenched,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to and: or, but, though, including, however, while, berengar, pathologies,
# Nearest to about: missing, widened, expressly, fonni, delegates, regarding, sei, entitled,
# Nearest to more: less, most, very, quite, rather, better, smaller, relatively,
# Nearest to state: states, barrows, government, sovereign, nightclub, anniversary, befriends, crown,
# Nearest to a: another, pilsner, krypton, dime, palermo, albion, the, baserunners,
# Nearest to people: men, children, women, person, persons, players, citizens, jews,
# Nearest to during: in, after, at, despite, before, under, until, when,
# Nearest to that: which, what, however, goryeo, whom, how, why, corel,
# Nearest to first: next, last, second, third, fourth, earliest, previous, smallest,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
